# %%
import pandas as pd

data = pd.read_csv("dataset.csv")
for i in range(0, 10):
    print("Headnote: \n\n")
    print(data["Headnote"][i], "\n")
    print("Decision: \n\n")
    print(data["Decisions"][i], "\n")
    print("------------------------------------------------------------------------------------------------------------------------------------- \n\n")
# Out:
# Headnote:
#
#
# The six appellants were convicted under s. 304 Part II with s. 34 of the Indian Penal Code by the Sessions Judge add their appeal was summarily dismissed by the High Court. On appeal by special leave, it was contended that s. 304, Part 11 could not be read with s. 34 Indian Penal Code because the second part of s. 304 excluded intention and was concerned with knowledge and the conviction was illegal.
#
# Decision:
#
#
# ...
